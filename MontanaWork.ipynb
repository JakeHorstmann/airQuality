# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
from pandas.core.common import SettingWithCopyWarning

from airQualFunctions import *
warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)

# %%
df = pd.read_csv("airquality_pm10_daily_summary.csv")

# %%
state = 'Montana'
StateData(df, state, state + 'Data')

MT = pd.read_csv(state + 'Data.csv')

# %%
MT.head()
# Out:
#       latitude   longitude  date_local event_type  arithmetic_mean  aqi  \
# 4    47.594395 -115.323746  2019-12-31       None             15.0   14
# 41   47.048537 -109.455315  2019-12-31       None              5.0    5
# 67   47.867900 -104.676944  2019-12-31       None              3.0    3
# 79   48.317507 -107.862471  2019-12-31       None              2.0    2
# 105  48.200540 -114.305334  2019-12-31       None             11.0   10
#
#     state_name county_name          days       colors
# 4      Montana     Sanders  10950.583333    steelblue
# 41     Montana      Fergus  10950.583333    slategrey
# 67     Montana    Richland  10950.583333    slateblue
# 79     Montana    Phillips  10950.583333          tan
# 105    Montana    Flathead  10950.583333  yellowgreen

# %%
PlotByCounty(MT)

# %%
MThazard = MT.loc[MT['aqi'] > 300]
MThazardNoInc = MThazard.loc[MThazard['event_type'] != 'Included']
MThazardInc = MThazard.loc[MThazard['event_type'] == 'Included']

print(MThazard.event_type.count(), MThazardInc.event_type.count(), MThazardNoInc.event_type.count())
# Out:
# 1 0 1

# %%
MThazardNoInc.head()
# Out:
#           latitude   longitude  date_local event_type  arithmetic_mean  aqi  \
# 4352354  45.070492 -110.636042  1991-06-11       None            452.0  335
#
#         state_name county_name        days  colors
# 4352354    Montana        Park  528.083333  sienna
